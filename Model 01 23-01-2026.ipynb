# %%
#mark={
    "maths":85,
    "Science":90,
    "physics":95
}
total = sum(mark.values())
average = total / len(mark)
print("Total=",total)
print("Average=",average)
# Out:
# Total= 270
# Average= 90.0

# %%
class crop:
  def __init__(self,name,Season,Expected_yield):
    self.name=name
    self.Season=Season
    self.Expected_yield=Expected_yield

  def total_production(self,Area):
    return self.Expected_yield*Area
area=10
rice=crop("rice","Kharif",20)
print("total rice production",rice.total_production(area),"Tons")
# Out:
# total rice production 200 Tons

# %%
x=5
y=2
z=x+y*3
print(z)
# Out:
# 11

# %%
a=10
b=a-3
a=a+1
print(a,b)
# Out:
# 11 7

# %%
name="Dattukumar"
age=25
print("Hello",name)
print("you are",age,"years old.")
# Out:
# Hello Dattukumar
# you are 25 years old.

# %%
name="Dattukumar"
age=25
print("welcome to phthon",name)
print("you are",age,"years old.")
# Out:
# welcome to phthon Dattukumar
# you are 25 years old.

# %%
mark=int(input("Enter mark"))
if mark >=90:
  print("Grade A")
elif mark >=75:
  print("Grade B")
else:
      print("Grade C")
# Out:
# Enter mark95
# Grade A

# %%
age=int(input("Enter age"))
if age<=12 or age>60:
  print("Discount availabe")
else:
  print("No Discount")
# Out:
# Enter age08
# Discount availabe

# %%
num=int(input("Enter number"))
if num%2==0:
  print("Even number")
else:
  print("Odd number")
# Out:
# Enter number05
# Odd number

# %%
year=int(input("Enter year:"))
if year %4==0:
  print("leap year")
else:
  print("not leap year")
# Out:
# Enter year:2023
# not leap year

# %%
n=int(input("enter n:"))
total=0
for i in range(1,n+1):
  total=total+i
print("total=",total)
# Out:
# enter n:10
# total= 55

# %%
marks=[56,78,90,45,88]

# Max
max_mark =marks[0]
for m in marks:
  if m > max_mark:
    max_mark = m


# Average
total = 0
for m in marks:
  total = total + m

average = total / len(marks)

# Count>=60
count = 0
for m in marks:
  if m >= 60:
    count = count + 1

print("max:", max_mark)
print("Average:", average)
print("count>=60:", count)
# Out:
# max: 90
# Average: 71.4
# count>=60: 3

# %%
def average_marks(marks_list):
  total =0
  for m in marks_list:
    total=total+m
    avg=total/len(marks_list)
    return avg
    data=[60,70,80]
    print("Average=",average_marks(data))

# %%
base_fees = int(input("Enter base_fees"))
age = int(input("Enter age"))

if age < 12:
    fees = base_fees * 0.5
elif age > 60:
    fees = base_fees * 0.3
else:
    fees = base_fees

print("fees_", fees)
# Out:
# Enter base_fees5000
# Enter age25
# fees_ 5000

# %%
def drop_lowest(marks):
  new_marks=marks.copy()
  new_marks.remove(min(new_marks))
  return new_marks

def average(marks):
  total=0
  for m in marks:
    total=total+m
  return total/len(marks)

def is_passing(avg,threshould):
  #return true or False
  if avg>= threshould:
    return True
  else:
    return False

#Main flow
marks_list=[45,60,75,30]
threshould=50
new_marks=drop_lowest(marks_list)
avg=average(new_marks)
result=is_passing(avg,threshould)
print("Marks after dropping lowest:",new_marks)
print("Average:",avg)
print("pass?",result)
# Out:
# Marks after dropping lowest: [45, 60, 75]
# Average: 60.0
# pass? True

# %%
student = [] # Initialize student list
# Add 03 students
for i in range(3):
    roll = int(input("Enter roll:"))
    name = input("Enter name:")
    m1 = int(input("Enter marks1:"))
    m2 = int(input("Enter marks2:"))
    m3 = int(input("Enter marks3:"))
    record = {
        "roll": roll,
        "name": name,
        "marks": [m1, m2, m3]
    }
    student.append(record)

# Print each student name and average mark
for s in student:
    marks = s["marks"]
    avg = sum(marks) / len(marks)
    print(s["roll"], s["name"], "Average:", avg)
# Out:
# Enter roll:2211
# Enter name:Ravi A J
# Enter marks1:99
# Enter marks2:98
# Enter marks3:97
# Enter roll:2255
# Enter name:Sneha Haridas
# Enter marks1:95
# Enter marks2:98
# Enter marks3:98
# Enter roll:0019
# Enter name:Dattukumar
# Enter marks1:98
# Enter marks2:99
# Enter marks3:98
# 2211 Ravi A J Average: 98.0
# 2255 Sneha Haridas Average: 97.0
# 19 Dattukumar  Average: 98.33333333333333

# %%
class livestock:
  def __init__(self, animal_type, age, weight, feed_rate_per_kg):
    self.animal_type = animal_type
    self.age = age
    self.weight = weight
    self.feed_rate_per_kg = feed_rate_per_kg

  def total_feed_requirement(self, number_of_animals):
    # Assuming the total feed requirement is weight * feed_rate_per_kg * number_of_animals
    return self.weight * self.feed_rate_per_kg * number_of_animals
