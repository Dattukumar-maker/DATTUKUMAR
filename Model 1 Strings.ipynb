# %%
#Positive indexing
word="Dattukumar"
print(word[0])
print(word[1])
# Out:
# D
# a

# %%
#Negative indexing
word="Dattukumar"
print(word[-2])
print(word[-1])
# Out:
# a
# r

# %%
 #String Slicing
text="Dattukumar"
print(text[0:6])
# Out:
# Dattuk

# %%
#String length
text="Dattukumar"
print(len(text))
# Out:
# 10

# %%
#Changing Case
"DATTUKUMAR".lower()
# Out:
# 'dattukumar'

# %%
#Changeing case
"dattukumar".upper()
# Out:
# 'DATTUKUMAR'

# %%
#Removing Extra Space
data="  dattukumar  "
print(data.strip())
# Out:
# dattukumar

# %%
#title
"Agri Business Management".title()
# Out:
# 'Agri Business Management'

# %%
#Splitting Strings
sentance="python is Very Good"
words= sentance.split()
print(words)
#Output: ['python', 'is', 'Very', 'Good']
# Out:
# ['python', 'is', 'Very', 'Good']

# %%
#joining Strings
words = ['Python', 'is', 'easy', 'to', 'learn']
print("".join(words))
# Out:
# Pythoniseasytolearn

# %%
#String Concatenation
first="Hello"
Second="Python"
print(first+" "+Second)
# Out:
# Hello Python

# %%
#String formating f-strings
name="Dattukumar"
age= 24
print(f"my name is {name} and i am {age} years old")
# Out:
# my name is Dattukumar and i am 24 years old

# %%
#Counting Characters
text="banana"
print(text.count("a"))
print(text.count("n"))
# Out:
# 3
# 2

# %%
#checking Start and End
text="Dattukumar"
print(text.startswith("D"))
print(text.endswith("a"))
# Out:
# True
# False
