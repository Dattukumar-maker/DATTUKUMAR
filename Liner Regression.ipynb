# %%
import numpy as np
from sklearn.linear_model import LinearRegression
#training data:past seasons
rainfall=np.array([[200],[180],[220],[210]])
yield_kg=np.array([[3200],[3000],[3500],[3400]])
#train supervised model
model=LinearRegression()
model.fit(rainfall,yield_kg)
#prediction yield for new season
model.predict([[380]])
# Out:
# array([[5557.14285714]])

# %%
from sklearn.cluster import KMeans
import pandas as pd
#soil data without labels
soil_data=pd.DataFrame({
    "ph":[6.5,6.8,7.2,7.5,6.6],
    "moisture":[30,35,45,50,32]

})
#group soil types automatically
kmeans=KMeans(n_clusters=2,random_state=0)
soil_data["group"]=kmeans.fit_predict(soil_data)
soil_data
# Out:
#     ph  moisture  group
# 0  6.5        30      1
# 1  6.8        35      1
# 2  7.2        45      0
# 3  7.5        50      0
# 4  6.6        32      1

# %%
import pandas as pd
#sample farm dataset
data={
    "rainfall_mm":[200,180,220,210,190],
    "soil_moisture":[30,35,45,50,32],
    "yield_kg":[3200,3000,3500,3400,3100]
}
df=pd.DataFrame(data)
df
# Out:
#    rainfall_mm  soil_moisture  yield_kg
# 0          200             30      3200
# 1          180             35      3000
# 2          220             45      3500
# 3          210             50      3400
# 4          190             32      3100

# %%
from sklearn.linear_model import LinearRegression
x=df[["rainfall_mm","soil_moisture"]]
y=df["yield_kg"]

model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
import pandas as pd
import numpy as np

# === PANDAS SERIES ===
print("=== Creating Pandas Series ===")

# From list with default index
yields = pd.Series([2500, 2800, 3100, 2900])
print(yields)

# With custom index (plot names)
yields = pd.Series(
    [2500, 2800, 3100, 2900],
    index=['Plot_A', 'Plot_B', 'Plot_C', 'Plot_D'],
    name='Yield_kg'
)
print(f"\nYields with labels:\n{yields}")

# From dictionary
soil_ph = pd.Series({
    'Field_1': 6.5,
    'Field_2': 7.1,
    'Field_3': 5.8,
    'Field_4': 6.8
})
print(f"\nSoil pH:\n{soil_ph}")

# === ACCESSING DATA ===
print("\n=== Accessing Data ===")
print(f"Plot_B yield: {yields['Plot_B']}")
print(f"First yield: {yields.iloc[0]}")
print(f"Last two: {yields.iloc[-2:]}")

# Boolean selection
high_yield = yields[yields > 2700]
print(f"\nHigh yields (>2700):\n{high_yield}")

# === SERIES OPERATIONS ===
print("\n=== Operations ===")
print(f"Mean yield: {yields.mean():.0f}")
print(f"Total yield: {yields.sum()}")

# Apply function
yields_tons = yields / 1000
print(f"\nIn tons:\n{yields_tons}")

# Modify with condition
bonus = yields.apply(lambda x: 500 if x > 2800 else 0)
print(f"\nBonus:\n{bonus}")
# Out:
# === Creating Pandas Series ===
# 0    2500
# 1    2800
# 2    3100
# 3    2900
# dtype: int64
#
# Yields with labels:
# Plot_A    2500
# Plot_B    2800
# Plot_C    3100
# Plot_D    2900
# Name: Yield_kg, dtype: int64
#
# Soil pH:
# Field_1    6.5
# Field_2    7.1
# Field_3    5.8
# Field_4    6.8
# dtype: float64
#
# === Accessing Data ===
# Plot_B yield: 2800
# First yield: 2500
# Last two: Plot_C    3100
# Plot_D    2900
# Name: Yield_kg, dtype: int64
#
# High yields (>2700):
# Plot_B    2800
# Plot_C    3100
# Plot_D    2900
# Name: Yield_kg, dtype: int64
#
# === Operations ===
# Mean yield: 2825
# Total yield: 11300
#
# In tons:
# Plot_A    2.5
# Plot_B    2.8
# Plot_C    3.1
# Plot_D    2.9
# Name: Yield_kg, dtype: float64
#
# Bonus:
# Plot_A      0
# Plot_B      0
# Plot_C    500
# Plot_D    500
# Name: Yield_kg, dtype: int64

# %%
import pandas as pd

# Create data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

rainfall = [20, 15, 30, 45, 80, 200,
            350, 300, 150, 60, 25, 10]

# Create Series
rain_series = pd.Series(rainfall, index=months)

# 1. Monsoon months (rainfall > 100)
monsoon_months = rain_series[rain_series > 100]
print("Monsoon Months:\n", monsoon_months)

# 2. Average monthly rainfall
average_rainfall = rain_series.mean()
print("\nAverage Monthly Rainfall:", average_rainfall)

# 3. Month with maximum rainfall
max_month = rain_series.idxmax()
max_value = rain_series.max()
print("\nMonth with Maximum Rainfall:", max_month, "(", max_value, ")")
# Out:
# Monsoon Months:
#  Jun    200
# Jul    350
# Aug    300
# Sep    150
# dtype: int64
#
# Average Monthly Rainfall: 107.08333333333333
#
# Month with Maximum Rainfall: Jul ( 350 )
