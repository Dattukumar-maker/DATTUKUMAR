# %%
file=open("Attendance.txt"."w")
file.write("student attendance/n Manasa Present/n Sneha Haridas Present/n Diksha Present/n Ravi absent /n Dattukumar present/n")
file.close()
# Out:
#   File "/tmp/ipykernel_7716/4201038790.py", line 1
#     file=open("Attendance.txt"."w")
#                                ^
# SyntaxError: invalid syntax

# %%
file=open("Attendance.txt","w")
file.write("student attendance/n Manasa Present/n Sneha Haridas Present/n Diksha Present/n Ravi absent /n Dattukumar present/n")
file.close()

# %%
file=open("Attendance.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# student attendance/n Manasa Present/n Sneha Haridas Present/n Diksha Present/n Ravi absent /n Dattukumar present/n

# %%
import pandas as pd
import numpy as np

# Create farm data
farm = pd.DataFrame({
    'plot': ['A', 'B', 'C', 'D', 'E', 'F'],
    'crop': ['Wheat', 'Rice', 'Wheat', 'Cotton', 'Rice', 'Wheat'],
    'yield_kg': [2500, 3200, 2800, 1800, 3100, 2600],
    'irrigated': [True, True, False, True, True, False]
})

print("=== Original Data ===")
print(farm)

# === BOOLEAN INDEXING ===
print("\n=== Boolean Indexing ===")

# High yield plots
high_yield = farm[farm['yield_kg'] > 2700]
print("High yield plots (>2700):")
print(high_yield)

# Wheat plots
wheat = farm[farm['crop'] == 'Wheat']
print("\nWheat plots:")
print(wheat)

# Multiple conditions
irrigated_wheat = farm[(farm['crop'] == 'Wheat') & (farm['irrigated'] == True)]
print("\nIrrigated wheat:")
print(irrigated_wheat)

# === LOC AND ILOC ===
print("\n=== loc (label-based) ===")
print(farm.loc[0:2, ['plot', 'yield_kg']])  # Rows 0-2, specific columns

print("\n=== iloc (position-based) ===")
print(farm.iloc[0:2, 1:3])  # First 2 rows, columns 1-2

# === QUERY METHOD ===
print("\n=== Query Method ===")
result = farm.query("yield_kg > 2500 and irrigated == True")
print(result)
# Out:
# === Original Data ===
#   plot    crop  yield_kg  irrigated
# 0    A   Wheat      2500       True
# 1    B    Rice      3200       True
# 2    C   Wheat      2800      False
# 3    D  Cotton      1800       True
# 4    E    Rice      3100       True
# 5    F   Wheat      2600      False
#
# === Boolean Indexing ===
# High yield plots (>2700):
#   plot   crop  yield_kg  irrigated
# 1    B   Rice      3200       True
# 2    C  Wheat      2800      False
# 4    E   Rice      3100       True
#
# Wheat plots:
#   plot   crop  yield_kg  irrigated
# 0    A  Wheat      2500       True
# 2    C  Wheat      2800      False
# 5    F  Wheat      2600      False
#
# Irrigated wheat:
#   plot   crop  yield_kg  irrigated
# 0    A  Wheat      2500       True
#
# === loc (label-based) ===
#   plot  yield_kg
# 0    A      2500
# 1    B      3200
# 2    C      2800
#
# === iloc (position-based) ===
#     crop  yield_kg
# 0  Wheat      2500
# 1   Rice      3200
#
# === Query Method ===
#   plot  crop  yield_kg  irrigated
# 1    B  Rice      3200       True
# 4    E  Rice      3100       True
